# %% [markdown]
# # Требования в DS проектах

# %% [markdown]
# * Возьмите за основу продукт компании “Нетология” - профессию Data Scientist.
# * Как бы Вы организовали аналитику по данному продукту?
# * Сформулируйте 2-3 ключевые метрики продукта
# * Какие данные Вам могут помочь в поиске инсайтов?
# * Опишите команду для работы с данными для данного продукта
# * Какие роли Вам будут нужны?
# * Чем они будут заниматься?

# %%
    Если говорить, что  профессия Data Scientist это только один из продуктов компании Нетологии, 
то тогда не имеет смысла создавать команду только под этот продукт. Внутри компании должна быть 
создана центролизованная система аналитики. 
    Структура команды может быть следующей: ETL специалист - специалист по БД, BI специалист, аналитик.  
    ETL специалист - специалист по БД занимается сбором данных из разных источников, CRM-системы, Google и 
Yandex аналитика, и тд., строит хранилище данных и дорабатывает его по требованию.  
BI специалист задействован только на отчетах. Аналитик занимается прогнозом, проведением AB тестирования, 
ищет инсайты в данных. Количество человек на каждой роли зависит от объема работ.
    Основные метрики для данного продукта:
1. % людей, заинтересовавшихся в продукте
2. % людей, купивших курс
3. % людей, закончивших курс
4. % людей, которые сменили профессию после курса 
    В данном случае нам могут помочь данные из  Google и Yandex аналитики,   CRM-системы и конечно не терять 
связь с выпускниками, отслеживать их карьерную траекторию, так как они являются живой рекламой курса
и могут привлечь новых студентов, а могут и наоборот :)
