# %% [markdown]
# # Математика для Data Science. Домашнее задание №2.

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %% [markdown]
# Загрузим датасет о ценах на дома в Бостоне.

# %%
from sklearn.datasets import load_boston

boston_dataset = load_boston()
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
price = boston_dataset.target

print(boston_dataset.data.shape)
# Out:
# (506, 13)

# %% [markdown]
# Каждый дом - это вектор в 13-мерном пространстве. Написать код для подсчета скалярного произведения двух первых домов из датасета.

# %%
x1 = boston_dataset.data[0] # дом 1
x2 = boston_dataset.data[1] # дом 2

# %%
x1@x2
# Out:
# 234704.86490859918

# %%
np.transpose(x1)@np.transpose(x2)
# Out:
# 234704.86490859918

# %% [markdown]
# Нарисовать два дома в 3-мерном пространстве (атрибуты выбрать самостоятельно)

# %%
a = np.array(boston.loc[0,['RM', 'AGE', 'TAX']])
b = np.array(boston.loc[1,['RM', 'AGE', 'TAX']])
print(a,b)
# Out:
# [  6.575  65.2   296.   ] [  6.421  78.9   242.   ]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')

x = np.array([a[0], b[0]])
y = np.array([a[1], b[1]])
z = np.array([a[2], b[2]])

ax.plot([0,x[0]], [0,y[0]], [0,z[0]])
ax.plot([0,x[1]], [0,y[1]], [0,z[1]])

ax.scatter(x[0], y[0], z[0], c='b', marker='o')
ax.scatter(x[1], y[1], z[1], c='r', marker='o')

ax.set_xlabel('RM')
ax.set_ylabel('AGE')
ax.set_zlabel('TAX')

plt.show()

# %% [markdown]
# Найти косинус угла между векторами x1 и x2

# %%
# Длина векторов
l1 = np.linalg.norm(x1)
l2 = np.linalg.norm(x2)

# %%
(x1@x2)/(l1*l2)
# Out:
# 0.994296998616362

# %% [markdown]
# Найти расстояние между точками x1 и x2.

# %%
math.sqrt((a[0]-b[0])**2+(a[1]-b[1])**2+(a[2]-b[2])**2)
# Out:
# 55.710983800324335

# %%
# или
math.sqrt(sum((a-b)**2))
# Out:
# 55.710983800324335

# %% [markdown]
# Задан объект в пространстве 2D. Изменить положение объекта (сместить по оси x на 300 пикселей, по оси y на 200 пикселей).

# %%
import numpy as np
import matplotlib.pyplot as plt

A = [
    [-100, -100, 1],
    [-100, 100, 1],
    [100, 100, 1],
    [0, 0, 1],
    [100, -100, 1],
    [-100, -100, 1]
    ]
A = np.array(A)
x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
A
# Out:
# array([[-100, -100,    1],
#        [-100,  100,    1],
#        [ 100,  100,    1],
#        [   0,    0,    1],
#        [ 100, -100,    1],
#        [-100, -100,    1]])

# %% [markdown]
# Уменьшить объект в два раза.

# %%
TransformArray = np.array([
    [0.5, 0, 0],
    [0, 0.5, 0],
    [0, 0, 0.5]
])

# %%
B = []
for point in A:
    new_point=np.dot(TransformArray,np.transpose(point))
    B.append(new_point)
B = np.array(B).astype(int)
print(B)
# Out:
# [[-50 -50   0]
#  [-50  50   0]
#  [ 50  50   0]
#  [  0   0   0]
#  [ 50 -50   0]
#  [-50 -50   0]]

# %%
x = B[:,0]
y = B[:,1]
plt.plot(x, y)
x = A[:,0]
y = A[:,1]
plt.plot(x, y, color='r')
plt.ylim([-200, 200])
plt.xlim([-200, 200])
plt.legend(['новый', 'исходный'])

# %% [markdown]
# Повернуть на 130 градусов.

# %%
from math import cos, sin, pi

theta = (-130) * 180/pi
TransformArray = np.array([
    [cos(theta), sin(theta), 0],
    [-sin(theta), cos(theta), 0],
    [0, 0, 1]
])

# %%
B = []
for point in A:
    new_point=np.dot(TransformArray,np.transpose(point))
    B.append(new_point)
B = np.array(B).astype(int)
print(B)
# Out:
# [[ 122   70    1]
#  [  70 -122    1]
#  [-122  -70    1]
#  [   0    0    1]
#  [ -70  122    1]
#  [ 122   70    1]]

# %%
plt.figure(
    figsize=(8, 8),
    )
x = B[:,0]
y = B[:,1]
plt.plot(x, y)
x = A[:,0]
y = A[:,1]
plt.plot(x, y, color='r')
plt.ylim([-200, 200])
plt.xlim([-200, 200])
plt.legend(['новый', 'исходный'])

# %% [markdown]
# Отразить объект относительно прямой y=x

# %%
plt.figure(
    figsize=(8, 8),
    )
A = [
    [-100, -100, 1],
    [-100, 100, 1],
    [100, 100, 1],
    [0, 0, 1],
    [100, -100, 1],
    [-100, -100, 1]
    ]
A = np.array(A)
x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
A

x5 = np.linspace(-200, 200, 100)                     
y5 = x5                        

plt.plot(x5, y5)

# %%
TransformArray = np.array([
    [0, 1, 0],
    [1, 0, 0],
    [0, 0, 1]
])

# %%
B = []
for point in A:
    new_point=np.dot(TransformArray,np.transpose(point))
    B.append(new_point)
B = np.array(B).astype(int)
print(B)
# Out:
# [[-100 -100    1]
#  [ 100 -100    1]
#  [ 100  100    1]
#  [   0    0    1]
#  [-100  100    1]
#  [-100 -100    1]]

# %%
plt.figure(
    figsize=(8, 8),
    )
x = B[:,0]
y = B[:,1]
plt.plot(x, y)
x = A[:,0]
y = A[:,1]
plt.ylim([-200, 200])
plt.xlim([-200, 200])
plt.legend(['новый', 'исходный'])
plt.plot(x5, y5)
