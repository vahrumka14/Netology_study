# %% [markdown]
# Домашнее задание "Визуализация данных в Python"

# %% [markdown]
# Построить 5 графиков по выбранным данным.
#
# Графики должны быть различных видов и использовать хотя бы 2 из рассмотренных на занятии библиотек.
#
# Для каждого описать, какого типа переменные участвуют в визуализации, какова её цель (например, посмотреть на корреляцию двух величин или на распределение значений) и почему выбрали именно такой тип графика.
#
#
#
# Откуда брать данные
#
# Можно взять свой датасет или воспользоваться одним из приведенных ниже:
#
# Данные IMDB;
# Данные NYC;
# Данные NBA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, ImageColorGenerator
import numpy as np
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg'
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')
# будем отображать графики прямо в jupyter'e
# %matplotlib inline

# %%
movies = pd.read_csv('/home/lena/Netology/Python/tmdb-5000-movie-dataset/tmdb_5000_movies.csv')

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %% [markdown]
# 1. Зависимость оценки фильма от его бюджета

# %%
n = movies[['budget', 'vote_average']]
n1 = n[n['budget'] >1000]
n2 = n1[n1['vote_average'] >0]

# %%
sns.jointplot(x='vote_average', y='budget', 
              data=n2, kind='reg', color="g")

# %% [markdown]
# Из графика видно, что нет прямой зависимости между бюджетом фильма и его оценкой. Также видно, что оценки распределены нормально, а бюджет - нет. Данный график помогает визуализировать двумерное распределение между двумя переменными.

# %% [markdown]
# Такой же вывод можно сделать классифицируя бюджет и в каждом классе найдя среднее значение оценки. Видно, что средняя оценка будет примерно одинаковой в каждой группе, то есть бюджет никак не влияет на оценку фильма.

# %%
def classif(row):
    if row['budget'] <= 1000000:
        return 'низкий'
    elif row['budget'] > 1000000 and row['budget'] <100000000:
        return 'средний'
    else:
        return 'высокий'

# %%
n2['budget'] = n2.apply(classif, axis=1)

# %%
n2.groupby('budget').mean()[['vote_average']]
# Out:
#          vote_average
# budget
# высокий      6.355625
# низкий       6.247500
# средний      6.235298

# %% [markdown]
# 2. Зависимость между сборами от фильма и месяцем выхода фильма

# %%
f2 = movies[['release_date', 'revenue']]

# %%
f2['month'] = pd.DatetimeIndex(f2['release_date']).month

# %%
f2.head()
# Out:
#   release_date     revenue  month
# 0   2009-12-10  2787965087   12.0
# 1   2007-05-19   961000000    5.0
# 2   2015-10-26   880674609   10.0
# 3   2012-07-16  1084939099    7.0
# 4   2012-03-07   284139100    3.0

# %%
f3 = f2[f2['revenue'] >1000]

# %%
f4 = f3.groupby('month')['revenue'].mean()

# %%
f4 = f4.reset_index()
f4.head(12)
# Out:
#     month       revenue
# 0     1.0  5.524350e+07
# 1     2.0  7.787713e+07
# 2     3.0  1.105462e+08
# 3     4.0  1.115287e+08
# 4     5.0  1.891698e+08
# 5     6.0  1.981227e+08
# 6     7.0  1.467477e+08
# 7     8.0  7.708148e+07
# 8     9.0  5.893552e+07
# 9    10.0  8.114189e+07
# 10   11.0  1.591548e+08
# 11   12.0  1.493512e+08

# %%
plt.barh(f4['month'], f4['revenue']) 
plt.xlabel('revenue') 
plt.ylabel('month')
# Out:
# Text(0, 0.5, 'month')

# %% [markdown]
# Из графика видно, что наибольшие сборы были в мае-июне.
# Данный график хорошо отображает сравнение по месяцам.

# %% [markdown]
# 3. Строим Wordcloud по ключевым словам

# %%
from ast import literal_eval

# %%
movies['keywords'] = movies['keywords'].apply(literal_eval)

# %%
def return_genres(row):
    genres_list = []
    for el in row:
        genres_list.append(el['name'])
    return genres_list

# %%
dd = movies['keywords'].map(return_genres)

# %%
l = []
d = {}
for i in movies['keywords'].map(return_genres):
    l.extend(i)
mytext = ','.join(l)
for j in l:
    if j not in d:
        d[j] = 1
    else:
        d[j] += 1

# %%
dd1 = sorted(d.items(), key=lambda kv: -kv[1])

# %%
dd1[0:15]
# Out:
# [('woman director', 324),
#  ('independent film', 318),
#  ('duringcreditsstinger', 307),
#  ('based on novel', 197),
#  ('murder', 189),
#  ('aftercreditsstinger', 170),
#  ('violence', 150),
#  ('dystopia', 139),
#  ('sport', 126),
#  ('revenge', 118),
#  ('sex', 111),
#  ('friendship', 106),
#  ('musical', 105),
#  ('biography', 105),
#  ('teenager', 99)]

# %%
wordcloud = WordCloud(max_font_size=50, background_color='white', 
                      max_words=170,relative_scaling=0.7,
                      normalize_plurals=False)
wordcloud.generate(mytext)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# Смысл данного графика показать некое "облако", заполненное ключевыми словами. Чем чаще слово встречается, тем большим шрифтом оно показано на графике. График очень удобен, когда работаем с текстом. Также была сделана доп. проверка по ключевым словам (рассчитана частота по ключевым словам) и действительно видно, что слова ('woman director', 324) и ('independent film', 318) встречаются чаще всего.

# %% [markdown]
# 4. Зависимость рейтинга от месяца выхода фильма

# %%
t = movies[['release_date', 'vote_average']]

# %%
t['month'] = pd.DatetimeIndex(t['release_date']).month

# %%
t.head()
# Out:
#   release_date  vote_average  month
# 0   2009-12-10           7.2   12.0
# 1   2007-05-19           6.9    5.0
# 2   2015-10-26           6.3   10.0
# 3   2012-07-16           7.6    7.0
# 4   2012-03-07           6.1    3.0

# %%
t2 = t[t['vote_average'] >0]

# %%
t3 = t2.groupby('month').agg(['median','min', 'max'])['vote_average'].sort_values('median', ascending=False)
t3 = t3.reset_index()
t3.head(12)
# Out:
#     month  median  min   max
# 0    12.0     6.5  2.3   8.3
# 1     9.0     6.4  1.0   8.5
# 2    11.0     6.4  1.0   8.3
# 3     5.0     6.3  3.0  10.0
# 4     6.0     6.3  2.0  10.0
# 5     7.0     6.3  3.5  10.0
# 6    10.0     6.3  3.5   8.3
# 7     2.0     6.1  3.0   8.3
# 8     4.0     6.1  2.0   8.2
# 9     1.0     6.0  0.5  10.0
# 10    3.0     6.0  2.7   8.4
# 11    8.0     6.0  1.9   9.3

# %%
sns.boxplot(x="month", y="vote_average", 
            data=t2)

# %% [markdown]
# Из графика видно, что медиана для всех месяцев примерно одинакова (это подтверждается и расчетами). Также видно большой разброс в негативных оценках по августу и сентябрю (возможно это связано с большим количеством фильмов в эти месяца). Но гипотеза, что есть зависимоть рейтинга от месяца выхода фильма - не подтверждается.

# %% [markdown]
# 5. Строим heatmap

# %%
g = movies[['budget','popularity', 'revenue', 'runtime', 'vote_average']]
g.head()
# Out:
#       budget  popularity     revenue  runtime  vote_average
# 0  237000000  150.437577  2787965087    162.0           7.2
# 1  300000000  139.082615   961000000    169.0           6.9
# 2  245000000  107.376788   880674609    148.0           6.3
# 3  250000000  112.312950  1084939099    165.0           7.6
# 4  260000000   43.926995   284139100    132.0           6.1

# %%
sns.heatmap(g.corr(),annot=True, fmt = ".2f", linewidths= 0.01)

# %% [markdown]
# Нужно сравнить пять числовых величин попарно для этого был выбран график тепловая карта.

# %% [markdown]
# Из графика видно, что есть зависимость между сборами от фильма и его бюджетом и популярностью, что действительно крайне логично.
